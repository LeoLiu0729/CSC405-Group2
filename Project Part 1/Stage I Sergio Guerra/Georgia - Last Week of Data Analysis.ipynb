# %%
import pandas as pd

cases_data = pd.read_csv('covid_confirmed_usafacts.csv')
cases_df = pd.DataFrame(cases_data)

cases_df[cases_df.loc[:, 'State'] == 'GA']
# Out:
#      countyFIPS            County Name State  StateFIPS  2020-01-22  \
# 397           0  Statewide Unallocated    GA         13           0
# 398       13001        Appling County     GA         13           0
# 399       13003       Atkinson County     GA         13           0
# 400       13005          Bacon County     GA         13           0
# 401       13007          Baker County     GA         13           0
# ..          ...                    ...   ...        ...         ...
# 552       13313      Whitfield County     GA         13           0
# 553       13315         Wilcox County     GA         13           0
# 554       13317         Wilkes County     GA         13           0
# 555       13319      Wilkinson County     GA         13           0
# 556       13321          Worth County     GA         13           0
#
#      2020-01-23  2020-01-24  2020-01-25  2020-01-26  2020-01-27  ...  \
# 397           0           0           0           0           0  ...
# ...

# %% [markdown]
# Using Jupyter Notebook, I was able to use conditional selection to choose the state of Georgia. In the first row of data, the county shows as `Statewide Unallocated`. This means that the data is for the state as a whole. The final 7 days of data in that row show that the Covid-19 Case rate was stable at `86,623`.

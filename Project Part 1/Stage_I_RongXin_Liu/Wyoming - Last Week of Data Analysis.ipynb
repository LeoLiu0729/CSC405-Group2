# %%
import pandas as pd

cases_data = pd.read_csv('covid_confirmed_usafacts.csv')
cases_df = pd.DataFrame(cases_data)

cases_df[cases_df.loc[:, 'State'] == 'WY']
# Out:
#       countyFIPS            County Name State  StateFIPS  2020-01-22  \
# 3169           0  Statewide Unallocated    WY         56           0
# 3170       56001         Albany County     WY         56           0
# 3171       56003       Big Horn County     WY         56           0
# 3172       56005       Campbell County     WY         56           0
# 3173       56007         Carbon County     WY         56           0
# 3174       56009       Converse County     WY         56           0
# 3175       56011          Crook County     WY         56           0
# 3176       56013        Fremont County     WY         56           0
# 3177       56015         Goshen County     WY         56           0
# 3178       56017    Hot Springs County     WY         56           0
# 3179       56019        Johnson County     WY         56           0
# 3180       56021        Laramie County     WY         56           0
# 3181       56023        Lincoln County     WY         56           0
# ...

# %% [markdown]
# Using the Pandas to Analysis last cases data upload to the cvs it end at July 2023. As we can see Wyoming does'nt have a Statewide Unallocated but we can see as a county all the Covid-19 Case rate was stable.

# %%
import pandas as pd

cases = pd.read_csv('covid_confirmed_usafacts.csv')
cases_df = pd.DataFrame(cases)

cases_df[cases_df.loc[:, 'State'] == 'VT']
# Out:
#       countyFIPS            County Name State  StateFIPS  2020-01-22  \
# 2851           0  Statewide Unallocated    VT         50           0
# 2852       50001        Addison County     VT         50           0
# 2853       50003     Bennington County     VT         50           0
# 2854       50005      Caledonia County     VT         50           0
# 2855       50007     Chittenden County     VT         50           0
# 2856       50009          Essex County     VT         50           0
# 2857       50011       Franklin County     VT         50           0
# 2858       50013     Grand Isle County     VT         50           0
# 2859       50015       Lamoille County     VT         50           0
# 2860       50017         Orange County     VT         50           0
# 2861       50019        Orleans County     VT         50           0
# 2862       50021        Rutland County     VT         50           0
# 2863       50023     Washington County     VT         50           0
# ...

# %% [markdown]
# When looking at the first row of data, the country shows as 'Statewide Unallocated'. This means that the data is showing for the state as a whole. During the final 7 days, the row shows that there was no changes and that the Covid-19 Case rate was stable.
